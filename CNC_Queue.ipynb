# %%
# !pip install pulp
# Out:
# Collecting pulp
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading PuLP-2.7.0-py3-none-any.whl (14.3 MB)
#      ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#       --------------------------------------- 0.2/14.3 MB 5.9 MB/s eta 0:00:03
#      - -------------------------------------- 0.5/14.3 MB 5.9 MB/s eta 0:00:03
#      -- ------------------------------------- 0.8/14.3 MB 6.1 MB/s eta 0:00:03
#      -- ------------------------------------- 1.0/14.3 MB 6.2 MB/s eta 0:00:03
#      -- ------------------------------------- 1.0/14.3 MB 6.6 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/14.3 MB 6.6 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/14.3 MB 6.6 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/14.3 MB 6.6 MB/s eta 0:00:02
#      -- ------------------------------------- 1.0/14.3 MB 6.6 MB/s eta 0:00:02
#      --- ------------------------------------ 1.2/14.3 MB 3.0 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.5/14.3 MB 3.2 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.7/14.3 MB 3.4 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.9/14.3 MB 3.6 MB/s eta 0:00:04
#      ------ --------------------------------- 2.2/14.3 MB 3.8 MB/s eta 0:00:04
#      ------ --------------------------------- 2.4/14.3 MB 4.0 MB/s eta 0:00:03
#      ------- -------------------------------- 2.8/14.3 MB 4.2 MB/s eta 0:00:03
#      -------- ------------------------------- 3.1/14.3 MB 4.4 MB/s eta 0:00:03
#      --------- ------------------------------ 3.4/14.3 MB 4.5 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.6/14.3 MB 4.5 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.9/14.3 MB 4.7 MB/s eta 0:00:03
#      ----------- ---------------------------- 4.2/14.3 MB 4.8 MB/s eta 0:00:03
#      ------------ --------------------------- 4.5/14.3 MB 4.9 MB/s eta 0:00:03
#      ------------- -------------------------- 4.8/14.3 MB 5.0 MB/s eta 0:00:02
#      -------------- ------------------------- 5.1/14.3 MB 5.0 MB/s eta 0:00:02
#      --------------- ------------------------ 5.4/14.3 MB 5.1 MB/s eta 0:00:02
#      --------------- ------------------------ 5.6/14.3 MB 5.1 MB/s eta 0:00:02
#      ---------------- ----------------------- 5.9/14.3 MB 5.3 MB/s eta 0:00:02
#      ----------------- ---------------------- 6.2/14.3 MB 5.3 MB/s eta 0:00:02
#      ------------------ --------------------- 6.6/14.3 MB 5.4 MB/s eta 0:00:02
#      ------------------- -------------------- 6.9/14.3 MB 5.4 MB/s eta 0:00:02
#      -------------------- ------------------- 7.2/14.3 MB 5.5 MB/s eta 0:00:02
#      --------------------- ------------------ 7.5/14.3 MB 5.6 MB/s eta 0:00:02
#      --------------------- ------------------ 7.8/14.3 MB 5.6 MB/s eta 0:00:02
#      ---------------------- ----------------- 8.1/14.3 MB 5.6 MB/s eta 0:00:02
#      ----------------------- ---------------- 8.4/14.3 MB 5.7 MB/s eta 0:00:02
#      ------------------------ --------------- 8.7/14.3 MB 5.7 MB/s eta 0:00:01
#      ------------------------- -------------- 9.0/14.3 MB 5.8 MB/s eta 0:00:01
#      -------------------------- ------------- 9.3/14.3 MB 5.8 MB/s eta 0:00:01
#      -------------------------- ------------- 9.5/14.3 MB 5.8 MB/s eta 0:00:01
#      --------------------------- ------------ 9.7/14.3 MB 5.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 10.2/14.3 MB 5.9 MB/s eta 0:00:01
#      ----------------------------- ---------- 10.5/14.3 MB 6.0 MB/s eta 0:00:01
#      ------------------------------ --------- 10.8/14.3 MB 6.0 MB/s eta 0:00:01
#      ------------------------------ --------- 11.0/14.3 MB 5.9 MB/s eta 0:00:01
#      ------------------------------- -------- 11.3/14.3 MB 6.8 MB/s eta 0:00:01
#      -------------------------------- ------- 11.6/14.3 MB 6.8 MB/s eta 0:00:01
#      --------------------------------- ------ 11.8/14.3 MB 6.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 12.1/14.3 MB 6.9 MB/s eta 0:00:01
#      ---------------------------------- ----- 12.4/14.3 MB 6.8 MB/s eta 0:00:01
#      ----------------------------------- ---- 12.7/14.3 MB 7.0 MB/s eta 0:00:01
#      ------------------------------------ --- 12.8/14.3 MB 6.9 MB/s eta 0:00:01
#      ------------------------------------- -- 13.3/14.3 MB 7.0 MB/s eta 0:00:01
#      -------------------------------------- - 13.6/14.3 MB 7.0 MB/s eta 0:00:01
#      -------------------------------------- - 13.9/14.3 MB 7.0 MB/s eta 0:00:01
#      ---------------------------------------  14.2/14.3 MB 7.0 MB/s eta 0:00:01
#      ---------------------------------------  14.2/14.3 MB 7.0 MB/s eta 0:00:01
#      ---------------------------------------- 14.3/14.3 MB 6.6 MB/s eta 0:00:00
# Installing collected packages: pulp
# Successfully installed pulp-2.7.0

# %%
# !pip install ortoolpy
# Out:
# Collecting ortoolpy
#   Obtaining dependency information for ortoolpy from https://files.pythonhosted.org/packages/68/a1/a7433cfc483e2425ba1b7304dab739bd268e4567f08c67e5b5cf76e908db/ortoolpy-0.6.4-py3-none-any.whl.metadata
#   Downloading ortoolpy-0.6.4-py3-none-any.whl.metadata (1.6 kB)
# Collecting more-itertools<11.0,>=10.1 (from ortoolpy)
#   Obtaining dependency information for more-itertools<11.0,>=10.1 from https://files.pythonhosted.org/packages/5a/cb/6dce742ea14e47d6f565589e859ad225f2a5de576d7696e0623b784e226b/more_itertools-10.1.0-py3-none-any.whl.metadata
#   Downloading more_itertools-10.1.0-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\dlwks\appdata\local\programs\python\python311\lib\site-packages (from ortoolpy) (2.0.3)
# Requirement already satisfied: pulp<3.0,>=2.7 in c:\users\dlwks\appdata\local\programs\python\python311\lib\site-packages (from ortoolpy) (2.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dlwks\appdata\roaming\python\python311\site-packages (from pandas>=1.5.3->ortoolpy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dlwks\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.5.3->ortoolpy) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dlwks\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.5.3->ortoolpy) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dlwks\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.5.3->ortoolpy) (1.26.0)
# Requirement already satisfied: six>=1.5 in c:\users\dlwks\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5.3->ortoolpy) (1.16.0)
# Downloading ortoolpy-0.6.4-py3-none-any.whl (28 kB)
# Downloading more_itertools-10.1.0-py3-none-any.whl (55 kB)
#    ---------------------------------------- 0.0/55.8 kB ? eta -:--:--
#    ---------------------------------------- 55.8/55.8 kB 2.8 MB/s eta 0:00:00
# Installing collected packages: more-itertools, ortoolpy
# Successfully installed more-itertools-10.1.0 ortoolpy-0.6.4
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
from itertools import product
from pulp import LpVariable, lpSum, value, LpProblem, LpMinimize, PULP_CBC_CMD
from ortoolpy import model_min, addvars, addvals, model_max

# %%
train = pd.read_csv(r'C:\Users\dlwks\OneDrive\바탕 화면\VSCode\HD_CNC\train.csv').drop(['X1'], axis = 1)
test = pd.read_csv(r'C:\Users\dlwks\OneDrive\바탕 화면\VSCode\HD_CNC\test.csv').drop(['Id', 'X1'], axis = 1)

display(train.head())
display(test.head())
# Out:
#       X2    X3    X4        X5  X6  X7     X8    Y1    Y2
# 0   56.3  67.5  22.5  AH32       4  97  PL973   467  2241
# 1  115.0  67.0  13.0  AH32       2  27  PL271  1058  1163
# 2   59.2  44.6  18.0  AH32-TM    1  14  PL141   270  1094
# 3   52.1  97.4  15.0  A         17  24  PL242   391  2604
# 4   42.9  58.7  14.5  A          4  23  PL233   232  1564
#       X2     X3    X4        X5  X6  X7     X8
# 0   80.6  104.8  11.0  A         29  23  PL234
# 1  141.8   34.2  17.5  A          2  91  PL911
# 2   77.2  103.3  17.0  A         10  97  PL973
# 3   95.5  131.0  18.0  A          2  23  PL234
# 4   91.7   36.1  19.0  AH32       1  27  PL271
